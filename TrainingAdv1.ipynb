# %% [markdown]
# <a href="https://colab.research.google.com/github/apichatsc03/pyBasic/blob/main/TrainingAdv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Recap Assigment#1

# %%
i = input(str())

for x in range(0, len(i)):
  if (int(x)%2):
    print("even")
  else:
    print("old")
# Out:
# 123
# old
# even
# old

# %% [markdown]
# pandas ex.

# %%
import pandas as pd # as = a.k.a
from google.colab import drive # access gDrive
drive.mount('/content/gdrive')
#Dataframe
#df=pd.read_excel('gdrive/My Drive/P1-OfficeSupplies.xlsx',sheet_name='P1-OfficeSupplies')
df=pd.read_excel('gdrive/My Drive/P1-OfficeSupplies.xlsx',sheet_name=0)
df
# Out:
# Mounted at /content/gdrive
#     Transaction  OrderDate      Rep     Item  Units  Unit Price  \
# 0           1.0 2014-07-04  Richard  Pen Set   62.0        4.99
# 1           2.0 2014-07-12     Nick   Binder   29.0        1.99
# 2           3.0 2014-07-21   Morgan  Pen Set   55.0       12.49
# 3           4.0 2014-07-29    Susan   Binder   81.0       19.99
# 4           5.0 2014-08-07  Matthew  Pen Set   42.0       23.95
# 5           6.0 2014-08-15  Richard   Pencil   35.0        4.99
# 6           7.0 2014-08-24    James     Desk    3.0      275.00
# 7           8.0 2014-09-01    Smith     Desk    2.0      125.00
# 8           9.0 2014-09-10     Bill   Pencil    7.0        1.29
# 9          10.0 2014-09-18  Richard  Pen Set   16.0       15.99
# 10         11.0 2014-09-27    James      Pen   76.0        1.99
# 11         12.0 2014-10-05   Morgan   Binder   28.0        8.99
# 12         13.0 2014-10-14   Thomas   Binder   57.0       19.99
# ...

# %%
pip install mysql-connector-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 23.5 MB 1.9 MB/s
# ...

# %%
# การสร้าง connection MYSQL
import mysql
import mysql.connector as msql
from mysql.connector import Error
try:
    conn = msql.connect(host='remotemysql.com',database='vRhyvS4Iqe',user='vRhyvS4Iqe',  
                        password='2E8bpkOVFk')#give ur username, password
except Error as e:
    print("Error while connecting to MySQL now ", e)

# %%
df=pd.read_sql("SELECT * FROM `P1-OfficeSupplies`", con=conn)
df
# Out:
#     Transaction   OrderDate      Rep     Item  Units  Unit Price  \
# 0             1  2014-07-04  Richard  Pen Set     62         5.0
# 1             2  2014-07-12     Nick   Binder     29         2.0
# 2             3  2014-07-21   Morgan  Pen Set     55        12.0
# 3             4  2014-07-29    Susan   Binder     81        20.0
# 4             5  2014-08-07  Matthew  Pen Set     42        24.0
# 5             6  2014-08-15  Richard   Pencil     35         5.0
# 6             7  2014-08-24    James     Desk      3       275.0
# 7             8  2014-09-01    Smith     Desk      2       125.0
# 8             9  2014-09-10     Bill   Pencil      7         1.0
# 9            10  2014-09-18  Richard  Pen Set     16        16.0
# 10           11  2014-09-27    James      Pen     76         2.0
# 11           12  2014-10-05   Morgan   Binder     28         9.0
# 12           13  2014-10-14   Thomas   Binder     57        20.0
# ...

# %%
pip install schedule
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import schedule
import time


def job():
  print("On Time")

# schedule.every(1).minutes.do(job)
schedule.every(10).seconds.do(job)
# schedule.every(3).hour.do(job)
# schedule.every().day.at("10:30").do(job)
# schedule.every().monday.do(job)
# schedule.every().wednesday.at("13:15").do(job)
# schedule.every().minute.at(":17").do(job)
while True:
    schedule.run_pending()
    time.sleep(1)
# Out:
# On Time
# On Time
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-c6a64fdcf1c0> in <module>
#      15 while True:
#      16     schedule.run_pending()
# ---> 17     time.sleep(1)
#
# KeyboardInterrupt:

# %%
# df["Rep"] -> option 1

# df.Rep -> option 2

# print(df.iloc[2]["OrderDate"]) -> option 3

# df.iloc[0:5]["Rep"] -> option 4

# check Data type
# print(df.dtypes)

# df.Transaction=df.Transaction.astype(str) -> change type

# df2=df.copy() -> copy

df2.Rep=df2.Rep.str.lower()
df2
# Out:
#    Transaction   OrderDate      Rep     Item  Units  Unit Price  \
# 0            1  2014-07-04  richard  Pen Set     62         5.0
# 1            2  2014-07-12     nick   Binder     29         2.0
# 2            3  2014-07-21   morgan  Pen Set     55        12.0
# 3            4  2014-07-29    susan   Binder     81        20.0
# 4            5  2014-08-07  matthew  Pen Set     42        24.0
# 5            6  2014-08-15  richard   Pencil     35         5.0
# 6            7  2014-08-24    james     Desk      3       275.0
# 7            8  2014-09-01    smith     Desk      2       125.0
# 8            9  2014-09-10     bill   Pencil      7         1.0
# 9           10  2014-09-18  richard  Pen Set     16        16.0
# 10          11  2014-09-27    james      Pen     76         2.0
# 11          12  2014-10-05   morgan   Binder     28         9.0
# 12          13  2014-10-14   thomas   Binder     57        20.0
# 13          14  2014-10-22  richard      Pen     64         9.0
# ...

# %%
df2=df2.drop(columns=["OrderDate", "Rep"])
df2
# Out:
#    Transaction     Item  Units  Unit Price           State
# 0            1  Pen Set     62         5.0         ALABAMA
# 1            2   Binder     29         2.0      CALIFORNIA
# 2            3  Pen Set     55        12.0  SOUTH CAROLINA
# 3            4   Binder     81        20.0            UTAH
# 4            5  Pen Set     42        24.0      WASHINGTON
# 5            6   Pencil     35         5.0    NORTH DAKOTA
# 6            7     Desk      3       275.0      NEW JERSEY
# 7            8     Desk      2       125.0      NEW JERSEY
# 8            9   Pencil      7         1.0        NEBRASKA
# 9           10  Pen Set     16        16.0            OHIO
# 10          11      Pen     76         2.0      NEW MEXICO
# 11          12   Binder     28         9.0      NEW MEXICO
# 12          13   Binder     57        20.0        COLORADO
# 13          14      Pen     64         9.0         MONTANA
# 14          15   Pencil     14         1.0        MICHIGAN
# ...

# %%
df3=df.copy()
df3=df3.filter(items=["Transaction", "State", "Units"])
df3
# Out:
#    Transaction           State  Units
# 0            1         ALABAMA     62
# 1            2      CALIFORNIA     29
# 2            3  SOUTH CAROLINA     55
# 3            4            UTAH     81
# 4            5      WASHINGTON     42
# 5            6    NORTH DAKOTA     35
# 6            7      NEW JERSEY      3
# 7            8      NEW JERSEY      2
# 8            9        NEBRASKA      7
# 9           10            OHIO     16
# 10          11      NEW MEXICO     76
# 11          12      NEW MEXICO     28
# 12          13        COLORADO     57
# 13          14         MONTANA     64
# 14          15        MICHIGAN     14
# 15          16    NORTH DAKOTA     15
# 16          17        ILLINOIS     11
# 17          18            OHIO     96
# 18          19            IOWA     94
# 19          20        KENTUCKY     67
# 20          21         MONTANA     28
# 21          22    NORTH DAKOTA     74
# 22          23            UTAH     95
# 23          24    PENNSYLVANIA     46
# ...

# %%
df4=df.copy()

# df4=df4[(df4.Item == "Pen Set") | (df4.Item == "Binder")] -> option 1
df4=df4.loc[(df4.Item.isin(["Binder", "Pen Set"]))]
df4
# Out:
#    Transaction   OrderDate      Rep     Item  Units  Unit Price  \
# 0            1  2014-07-04  Richard  Pen Set     62         5.0
# 1            2  2014-07-12     Nick   Binder     29         2.0
# 2            3  2014-07-21   Morgan  Pen Set     55        12.0
# 3            4  2014-07-29    Susan   Binder     81        20.0
# 4            5  2014-08-07  Matthew  Pen Set     42        24.0
# 9           10  2014-09-18  Richard  Pen Set     16        16.0
# 11          12  2014-10-05   Morgan   Binder     28         9.0
# 12          13  2014-10-14   Thomas   Binder     57        20.0
# 16          17  2014-11-17     Alex   Binder     11         5.0
# 17          18  2014-11-25  Matthew  Pen Set     96         5.0
# 18          19  2014-12-04     Alex   Binder     94        20.0
# 20          21  2014-12-21   Rachel   Binder     28         5.0
# 21          22  2014-12-29    Susan  Pen Set     74        16.0
# 23          24  2015-01-15     Bill   Binder     46         9.0
# ...

# %%
df_replace = df4.copy()

from google.colab import files
df_replace.to_excel('Export.xlsx',sheet_name='Output')
files.download('Export.xlsx')

# %%
df5 = df.copy()
# shape check lenght col, row
df.shape
#concat
df_combine = pd.concat([df, df5])
df_combine

#drop duplicate
df_combine = df_combine.drop_duplicates();
df_combine
# Out:
#    Transaction   OrderDate      Rep     Item  Units  Unit Price  \
# 0            1  2014-07-04  Richard  Pen Set     62         5.0
# 1            2  2014-07-12     Nick   Binder     29         2.0
# 2            3  2014-07-21   Morgan  Pen Set     55        12.0
# 3            4  2014-07-29    Susan   Binder     81        20.0
# 4            5  2014-08-07  Matthew  Pen Set     42        24.0
# 5            6  2014-08-15  Richard   Pencil     35         5.0
# 6            7  2014-08-24    James     Desk      3       275.0
# 7            8  2014-09-01    Smith     Desk      2       125.0
# 8            9  2014-09-10     Bill   Pencil      7         1.0
# 9           10  2014-09-18  Richard  Pen Set     16        16.0
# 10          11  2014-09-27    James      Pen     76         2.0
# 11          12  2014-10-05   Morgan   Binder     28         9.0
# 12          13  2014-10-14   Thomas   Binder     57        20.0
# 13          14  2014-10-22  Richard      Pen     64         9.0
# ...
