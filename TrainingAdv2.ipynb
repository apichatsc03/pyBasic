# %% [markdown]
# <a href="https://colab.research.google.com/github/apichatsc03/pyBasic/blob/main/TrainingAdv2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# data from United Nations World Population Prospects (Revision 2019)
# https://population.un.org/wpp/, license: CC BY 3.0 IGO
year = [1950, 1960, 1970, 1980, 1990, 2000, 2010, 2018]
population_by_continent = {
    'africa': [228, 284, 365, 477, 631, 814, 1044, 1275],
    'americas': [340, 425, 519, 619, 727, 840, 943, 1006],
    'asia': [1394, 1686, 2120, 2625, 3202, 3714, 4169, 4560],
    'europe': [220, 253, 276, 295, 310, 303, 294, 293],
    'oceania': [12, 15, 19, 22, 26, 31, 36, 39],
}

fig, ax = plt.subplots()
ax.stackplot(year, population_by_continent.values(),
             labels=population_by_continent.keys(), alpha=0.8)
ax.legend(loc='upper left')
ax.set_title('World population')
ax.set_xlabel('Year')
ax.set_ylabel('Number of people (millions)')

plt.show()

# %% [markdown]
# Basic grah

# %%
xpoint = [1,3,5]
ypoint = [2,4,6]
plt.plot(xpoint, ypoint)
plt.show()

# %%
import pandas as pd # as = a.k.a
from google.colab import drive # access gDrive
drive.mount('/content/gdrive')
#Dataframe
#df=pd.read_excel('gdrive/My Drive/P1-OfficeSupplies.xlsx',sheet_name='P1-OfficeSupplies')
df=pd.read_excel('gdrive/My Drive/P1-OfficeSupplies.xlsx',sheet_name=0)
df
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#     Transaction  OrderDate      Rep     Item  Units  Unit Price  \
# 0           1.0 2014-07-04  Richard  Pen Set   62.0        4.99
# 1           2.0 2014-07-12     Nick   Binder   29.0        1.99
# 2           3.0 2014-07-21   Morgan  Pen Set   55.0       12.49
# 3           4.0 2014-07-29    Susan   Binder   81.0       19.99
# 4           5.0 2014-08-07  Matthew  Pen Set   42.0       23.95
# 5           6.0 2014-08-15  Richard   Pencil   35.0        4.99
# 6           7.0 2014-08-24    James     Desk    3.0      275.00
# 7           8.0 2014-09-01    Smith     Desk    2.0      125.00
# 8           9.0 2014-09-10     Bill   Pencil    7.0        1.29
# 9          10.0 2014-09-18  Richard  Pen Set   16.0       15.99
# 10         11.0 2014-09-27    James      Pen   76.0        1.99
# 11         12.0 2014-10-05   Morgan   Binder   28.0        8.99
# ...

# %%
#Plot data label on chart
# for x,y in zip(df['Units'],df['Unit Price']):
#     label = f"({x},{y})"
#     plt.annotate(label, # this is the text
#                  (x,y), # these are the coordinates to position the label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,10), # distance from text to points (x,y)
#                  ha='center') # horizontal alignment can be left, right or center
# plt.show()

# %%
from datetime import datetime

df_group = df.copy()

df_group["Month"] = df_group.OrderDate.dt.month

df_group

df_pivot = df_group.pivot_table(index=["Month"], values=["Units"], aggfunc="sum")

df_pivot
# Out:
#        Units
# Month
# 1      191.0
# 2      154.0
# 3      113.0
# 4      297.0
# 5      255.0
# 6      155.0
# 7      227.0
# 8       80.0
# 9      101.0
# 10     163.0
# 11     122.0
# 12     263.0

# %%
import matplotlib.pyplot as plt



plt.plot(df.OrderDate, df.Units, color="g", )
plt.xlabel("Order Date")
plt.ylabel("Units")
plt.show()

# %%
plt.plot(df_pivot.index, df_pivot.values, color="g")
plt.xlabel("Month")
plt.ylabel("Units")
plt.show()

# %%
df_pivot_sell= df.pivot_table(index=["Rep"], values="Units", aggfunc="sum")

df_pivot_sell2 = df_pivot_sell.reset_index()

df_pivot_sell2

fig=plt.figure(figsize=(10,5))

plt.pie(df_pivot_sell2.Units, labels=df_pivot_sell2.Rep, autopct="%.0f%%",explode=[0.2,0,0,0,0,0,0,0,0.2,0,0])

plt.show()

# %%
fig=plt.figure(figsize=(10,10))
plt.bar(df_pivot_sell2.Rep, df_pivot_sell2.Units)

plt.show()

# %%
plt.scatter(df.Units, df["Unit Price"], alpha=0.9)
plt.scatter(df.Units, df.Transaction, alpha=0.9, color="g")
plt.show()

# %%
plt.scatter( df.Units, df["Unit Price"], df.Transaction,alpha=0.9)

plt.show()
